# %%
#Task 2.1
import random

def generateFood(field):
    x = random.randint(0, 29)
    y = random.randint(0, 19)
    while(field[y][x] in ['X', 'O']):
        x = random.randint(0, 29)
        y = random.randint(0, 19)

    field[y][x] = 'F'

def display(field):
    for row in field:
        for index, column in enumerate(row):
            if index == len(row) - 1:
                print(column)
            else:
                print(column, end = '')

field = []
field.append(['X' for i in range(30)])
for i in range(18):
    field.append(['X'] + ['.' for j in range(28)] + ['X'])
field.append(['X' for i in range(30)])
field[9][14] = 'O'
generateFood(field)
display(field)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X...................F........X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X.............O..............X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
#Task 2.2
playerX = 14
playerY = 9
lastMove = None
display(field)
while(health > 0):
    move = input("Enter your move: ")
    if move == '':
        move = lastMove
    
    if move.lower() not in ['w', 'a', 's', 'd']:
        print("Invalid move!")
        continue
    
    lastMove = move
    field[playerY][playerX] = '.'
    
    if move == 'w':
        playerY -= 1
    
    elif move == 'a':
        playerX -= 1
        
    elif move == 's':
        playerY += 1
        
    elif move == 'd':
        playerX += 1
    
    if field[playerY][playerX] == 'X':
        playerY = 9
        playerX = 14
        field[playerY][playerX] = 'O'
        
    elif field[playerY][playerX] == 'F':
        field[playerY][playerX] = 'O'
    
    else:
        field[playerY][playerX] = 'O'
        
    display(field)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X...................F........X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X.............O..............X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
#Task 2.3               
playerX = 14
playerY = 9
lastMove = None
score = 0
health = 3
display(field)
while(health > 0):
    move = input("Enter your move: ")
    if move == '':
        move = lastMove
    
    if move.lower() not in ['w', 'a', 's', 'd']:
        print("Invalid move!")
        continue
    
    lastMove = move
    field[playerY][playerX] = '.'
    
    if move == 'w':
        playerY -= 1
    
    elif move == 'a':
        playerX -= 1
        
    elif move == 's':
        playerY += 1
        
    elif move == 'd':
        playerX += 1
    
    if field[playerY][playerX] == 'X':
        playerY = 9
        playerX = 14
        health -= 1
        field[playerY][playerX] = 'O'
        
    elif field[playerY][playerX] == 'F':
        score += 1
        field[playerY][playerX] = 'O'
        generateFood(field)
    
    else:
        field[playerY][playerX] = 'O'
        
    display(field)
    
print("GAME OVER")
print(f"Score: {score}")
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X.............O..............X
# X............................X
# X............................X
# X............................X
# X........F...................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Enter your move: s
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# X............................X
# ...
