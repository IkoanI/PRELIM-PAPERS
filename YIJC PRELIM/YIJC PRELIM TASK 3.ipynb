# %%
#Task 3.1
class Node:
    def __init__(self, NewTreeItem):
        self.Data = NewTreeItem
        self.Left = None
        self.Right = None
        
    def SetLeft(self, x):
        self.Left = x
    
    def SetRight(self, y):
        self.Right = y
        
    def GetData(self): 
        return self.Data
    
    def GetLeft(self):
        return self.Left
    
    def GetRight(self):
        return self.Right
        
class BSTree:
    def __init__(self):
        self.ThisTree = []
        self.Root = None
        self.NextFree = 0
        
    def AddItem(self, NewTreeItem):
        pass
    
    def InOrderTraversal(self):
        pass

# %%
#Task 3.2
class Node:
    def __init__(self, NewTreeItem):
        self.Data = NewTreeItem
        self.Left = None
        self.Right = None
        
    def SetLeft(self, x):
        self.Left = x
    
    def SetRight(self, y):
        self.Right = y
        
    def GetData(self): 
        return self.Data
    
    def GetLeft(self):
        return self.Left
    
    def GetRight(self):
        return self.Right
        
class BSTree:
    def __init__(self):
        self.ThisTree = []
        self.Root = None
        self.NextFree = 0
        
    def AddItem(self, NewTreeItem):
        if self.Root == None:
            self.ThisTree.append(Node(NewTreeItem))
            self.Root = self.NextFree
            self.NextFree += 1 
        else:
            Current = self.Root
            LastMove = 'X'
        
            while(Current is not None):
                Previous = Current
                if NewTreeItem < self.ThisTree[Current].GetData():
                    LastMove = 'L'
                    Current = self.ThisTree[Current].GetLeft()
                else:
                    LastMove = 'R'
                    Current = self.ThisTree[Current].GetRight()

            if LastMove == 'R':
                self.ThisTree[Previous].SetRight(self.NextFree)
            else:
                self.ThisTree[Previous].SetLeft(self.NextFree)

            self.ThisTree.append(Node(NewTreeItem))  
            self.NextFree += 1
    
    def InOrderTraversal(self):
        pass

# %%
#Task 3.3
BST = BSTree()
BST.AddItem("INDIA")
BST.AddItem("NEPAL")
BST.AddItem("MALAYSIA")
BST.AddItem("SINGAPORE")
BST.AddItem("BURMA")
BST.AddItem("CANADA")
BST.AddItem("LATVIA")
print(f"{'Index':<15}{'Data value':<15}{'Left pointer':<15}{'Right pointer':<15}")
for index, node in enumerate(BST.ThisTree):
    print(f"{index:<15}{node.GetData():<15}{str(node.GetLeft()):<15}{str(node.GetRight()):<15}")
# Out:
# Index          Data value     Left pointer   Right pointer
# 0              INDIA          4              1
# 1              NEPAL          2              3
# 2              MALAYSIA       6              None
# 3              SINGAPORE      None           None
# 4              BURMA          None           5
# 5              CANADA         None           None
# 6              LATVIA         None           None

# %%
#Task 3.4
class Node:
    def __init__(self, NewTreeItem):
        self.Data = NewTreeItem
        self.Left = None
        self.Right = None
        
    def SetLeft(self, x):
        self.Left = x
    
    def SetRight(self, y):
        self.Right = y
        
    def GetData(self): 
        return self.Data
    
    def GetLeft(self):
        return self.Left
    
    def GetRight(self):
        return self.Right
        
class BSTree:
    def __init__(self):
        self.ThisTree = []
        self.Root = None
        self.NextFree = 0
        
    def AddItem(self, NewTreeItem):
        if self.Root == None:
            self.ThisTree.append(Node(NewTreeItem))
            self.Root = self.NextFree
            self.NextFree += 1 
        else:
            Current = self.Root
            LastMove = 'X'
        
            while(Current is not None):
                Previous = Current
                if NewTreeItem < self.ThisTree[Current].GetData():
                    LastMove = 'L'
                    Current = self.ThisTree[Current].GetLeft()
                else:
                    LastMove = 'R'
                    Current = self.ThisTree[Current].GetRight()

            if LastMove == 'R':
                self.ThisTree[Previous].SetRight(self.NextFree)
            else:
                self.ThisTree[Previous].SetLeft(self.NextFree)

            self.ThisTree.append(Node(NewTreeItem))  
            self.NextFree += 1
    
    def InOrderTraversal(self, root):
        if root is None:
            return
        else:
            self.InOrderTraversal(self.ThisTree[root].GetLeft())
            print(self.ThisTree[root].GetData())
            self.InOrderTraversal(self.ThisTree[root].GetRight())
            
BST = BSTree()
BST.AddItem("INDIA")
BST.AddItem("NEPAL")
BST.AddItem("MALAYSIA")
BST.AddItem("SINGAPORE")
BST.AddItem("BURMA")
BST.AddItem("CANADA")
BST.AddItem("LATVIA")
BST.InOrderTraversal(BST.Root)
# Out:
# BURMA
# CANADA
# INDIA
# LATVIA
# MALAYSIA
# NEPAL
# SINGAPORE
